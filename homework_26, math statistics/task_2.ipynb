# %%
from task_2 import MathStat
from task_2 import Draw


object_math = MathStat([10, 13, 10, 9, 9, 12, 12, 6, 7, 9, 8, 9, 11, 9, 14, 13, 9, 8, 8, 7, 10, 10, 11, 11, 11, 12, 8, 7, 9 ,10, 14, 13, 8, 8, 9, 10, 11, 11, 12, 12])
object_drow = Draw(object_math)

# %%
print(object_drow.table())
# Out:
#              1      2     3    4      5      6       7       8      9
# X = x_i  6.000  7.000  8.00  9.0  10.00  11.00  12.000  13.000  14.00
# Ni       1.000  3.000  6.00  8.0   6.00   6.00   5.000   3.000   2.00
# Wi       0.025  0.075  0.15  0.2   0.15   0.15   0.125   0.075   0.05

# %%
print(object_math.get_frequency())
print(object_math.get_relative_frequency())
# Out:
# {6: 1, 7: 3, 8: 6, 9: 8, 10: 6, 11: 6, 12: 5, 13: 3, 14: 2}
# {6: 0.025, 7: 0.075, 8: 0.15, 9: 0.2, 10: 0.15, 11: 0.15, 12: 0.125, 13: 0.075, 14: 0.05}

# %%
print(f"Mathematically, the sample size {object_math.get_size()}")
print(f"The sample median {object_math.get_median()}")
print(f"The sample mode {object_math.get_mode()}")
# Out:
# Mathematically, the sample size 8
# The sample median 10
# The sample mode 9

# %%
print(f"The sample average {object_math.get_sample_average()}")
print(f"The sampling variance {object_math.sample_dispersion()}")
print(f"The sample standard deviation {object_math.standard_deviation()}")
# Out:
# The sample average 10.0
# The sampling variance 4.0
# The sample standard deviation 2.0

# %%
print(f"Empirical sampling distribution function is {object_math.get_Empirical_distribution_function()}")
# Out:
# Empirical sampling distribution function is {0.025: 6, 0.1: 7, 0.25: 8, 0.45: 9, 0.6: 10, 0.75: 11, 0.875: 12, 0.95: 13, 1.0: 14}

# %% [markdown]
# $$
# F*(x) = \left\{
#     \begin{array}\\
#         0 & \mbox{if } \ x \le\ 6 \\
#         0.025 & \mbox{if } \ 6 < x \le 7 \\
#         0.1 & \mbox{if } \ 7 < x \le 8 \\
#         0.25 & \mbox{if } \ 8 < x \le 9 \\
#         0.45 & \mbox{if } \ 9 < x \le 10 \\
#         0.6 & \mbox{if } \ 10 < x \le 11 \\
#         0.75 & \mbox{if } \ 11 < x \le 12 \\
#         0.875 & \mbox{if } \ 12 < x \le 13 \\
#         0.95 & \mbox{if } \ 13 < x \le 14 \\
#         1 & \mbox{if } \ x \gt 14 \\
#     \end{array}
# \right.
# $$

# %%
object_drow.polygon_of_frequencies()

# %%
object_drow.relative_polygon()

# %%
object_drow.empirical_dist_func()
