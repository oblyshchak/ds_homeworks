# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_excel('cars.xlsx')
data
# Out:
#                             name     cost  fuel consumption  engine capacity  \
# 0            Mitsubishi ASX 2022  1120000               7.9              2.0
# 1                 Ford Kuga 2022  1555617               6.4              1.5
# 2       Citroen C5 Aircross 2022  1252060               6.4              2.0
# 3            Opel Grandland 2023  1081270               4.4              1.5
# 4           Hyundai Elantra 2021   912600               6.9              1.6
# 5              Peugeot 3008 2022  1324230               5.5              2.0
# 6   Mercedes-Benz GLS-Class 2022  4410915               7.5              2.0
# 7             Suzuki Vitara 2022   740000               6.2              1.6
# 8            Nissan Qashqai 2022  1024360               5.8              1.3
# 9        Volkswagen Touareg 2022  3000000               8.9              3.0
# 10             Toyota Camry 2022   186538               6.8              2.5
# 11   Skoda Kodiaq Sportline 2023  1840000               5.5              2.0
# 12              Nissan Juke 2022  1111390               4.8              1.0
# 13               Volvo XC60 2022  1970000               5.7              2.0
# 14              Chery Tiggo 2022   603100               6.6              1.5
# 15      Land Rover Defender 2022  3614505               8.3              3.0
# 16        Volkswagen Tiguan 2023  1875351               8.4              2.0
# 17            Infiniti QX80 2022  3217200              15.6              5.6
# 18              Mazda CX-30 2022  1159200               5.5              2.0
# 19           Hyundai Tucson 2022  1253600               4.8              1.6
#
#     max speed  carrying capacity
# 0         191                515
# 1         200                534
# 2         211                570
# 3         195                552
# 4         195                565
# 5         201                564
# 6         215                665
# 7         180                610
# 8         196                605
# 9         250                770
# 10        210                470
# 11        218                720
# 12        180                518
# 13        180                623
# 14        186                467
# 15        195                827
# 16        240                458
# 17        210                458
# 18        194                610
# 19        180                625

# %%
cost_dollar = 36.88
data['cost in dollars'] = (data['cost'] / cost_dollar).round(2)

# %%
sort_frame = data.sort_values(by=['fuel consumption', 'cost in dollars'])
sort_frame
# Out:
#                             name     cost  fuel consumption  engine capacity  \
# 3            Opel Grandland 2023  1081270               4.4              1.5
# 12              Nissan Juke 2022  1111390               4.8              1.0
# 19           Hyundai Tucson 2022  1253600               4.8              1.6
# 18              Mazda CX-30 2022  1159200               5.5              2.0
# 5              Peugeot 3008 2022  1324230               5.5              2.0
# 11   Skoda Kodiaq Sportline 2023  1840000               5.5              2.0
# 13               Volvo XC60 2022  1970000               5.7              2.0
# 8            Nissan Qashqai 2022  1024360               5.8              1.3
# 7             Suzuki Vitara 2022   740000               6.2              1.6
# 2       Citroen C5 Aircross 2022  1252060               6.4              2.0
# 1                 Ford Kuga 2022  1555617               6.4              1.5
# 14              Chery Tiggo 2022   603100               6.6              1.5
# 10             Toyota Camry 2022   186538               6.8              2.5
# 4           Hyundai Elantra 2021   912600               6.9              1.6
# 6   Mercedes-Benz GLS-Class 2022  4410915               7.5              2.0
# 0            Mitsubishi ASX 2022  1120000               7.9              2.0
# 15      Land Rover Defender 2022  3614505               8.3              3.0
# 16        Volkswagen Tiguan 2023  1875351               8.4              2.0
# 9        Volkswagen Touareg 2022  3000000               8.9              3.0
# 17            Infiniti QX80 2022  3217200              15.6              5.6
#
#     max speed  carrying capacity  cost in dollars
# 3         195                552         29318.60
# 12        180                518         30135.30
# 19        180                625         33991.32
# 18        194                610         31431.67
# 5         201                564         35906.45
# 11        218                720         49891.54
# 13        180                623         53416.49
# 8         196                605         27775.49
# 7         180                610         20065.08
# 2         211                570         33949.57
# 1         200                534         42180.50
# 14        186                467         16353.04
# 10        210                470          5057.97
# 4         195                565         24745.12
# 6         215                665        119601.82
# 0         191                515         30368.76
# 15        195                827         98007.19
# 16        240                458         50850.08
# 9         250                770         81344.90
# 17        210                458         87234.27

# %%
fid, ax = plt.subplots()
plt.plot(sort_frame['fuel consumption'], sort_frame['cost in dollars'], color = 'blue', linewidth = 3)
plt.xlabel("fuel consumption, l")
plt.ylabel("cost, $")
# Out:
# Text(0, 0.5, 'cost, $')

# %%
plt.scatter(sort_frame['fuel consumption'], sort_frame['max speed'], color = 'red', marker = '^')
plt.xlabel("fuel consumption, l")
plt.ylabel("max speed, km/h")
# Out:
# Text(0, 0.5, 'max speed, km/h')

# %%
plt.scatter(sort_frame['carrying capacity'], sort_frame['max speed'], color = 'orange', marker = 'o')
plt.xlabel("carrying capacity, kg")
plt.ylabel("max speed, km/h")
# Out:
# Text(0, 0.5, 'max speed, km/h')

# %%
plt.hist(sort_frame['max speed'], 5, color = 'purple')
plt.ylabel("frequency")
plt.xlabel("max speed, km/h")
# Out:
# Text(0.5, 0, 'max speed, km/h')
