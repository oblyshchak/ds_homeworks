# %%
group = 37
math = 15
physics = 16
chemistry = 19

# %% [markdown]
# math ∩ physics ∩ chemistry = 4
# math ∩ physics = 7
# math ∩ chemistry = 9
# physics ∩ chemistry = 6

# %%
#students, who got 2 well results
m_p_c = 4
m_p = 7 - m_p_c
m_c = 9 - m_p_c
p_c = 6 - m_p_c

students_2_res = m_p + m_c + p_c
print(students_2_res)
# Out:
# 10

# %%
#students, who got 1 well result
math_only = math - m_p - m_c - m_p_c
print(math_only)
physics_only = physics - p_c - m_p - m_p_c
print(physics_only)
chemistry_only = chemistry - p_c - m_c - m_p_c
print(chemistry_only)

students_1_res = math_only + physics_only + chemistry_only
print(students_1_res)
# Out:
# 3
# 7
# 8
# 18

# %%
#students, who got any good result
students_0 = group - m_p_c - students_1_res - students_2_res
print(students_0)
# Out:
# 5

# %% [markdown]
# ![Figure_1.png](attachment:Figure_1.png)
